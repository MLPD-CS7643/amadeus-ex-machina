# %%
# %load_ext autoreload
# %autoreload 2

# System imports
import sys
import os

# Add the parent directory of 'notebooks' to sys.path
parent_dir = os.path.abspath(os.path.join(os.getcwd(), "../.."))  # Move one level up
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

# %%
import torch
from pathlib import Path
from solver import Solver
from griddy.griddy_tuna import hit_griddy, SearchMethod
from models.CRNN import CRNNModel
from data.data_loader import MirDataProcessor
from utils.model_utils import get_device
from solver import TrialMetric

# %%
device = get_device()
print(f"Device is {device}")

# %%
# If you have already ran the downloader, change the value of download to False
download = False

# Reprocess for different dataset type while bypassing download
reprocess = True

# Download and build useable train/test data out of the MIR Billboard dataset
data_processer = MirDataProcessor(output_dir='data', download=download, batch_size=256, process_sequential=True, seq_length=8, overlap_sequence=True, use_median=True) # your notebook should be in its own directory to begin with, this should create the "data" folder inside that
if download:
    data_processer.process_billboard_data(log_fail_only=False) # you may need to reprocess the downloaded data into sequential or tabular based on your model
if reprocess:
    data_processer.dataset.download(partial_download=['metadata'])
    data_processer.process_billboard_data(combined_notation=True, chord_vocab='majmin7inv', log_fail_only=False)
    # combined notation is standard billboard notation (C:maj), setting False creates separate CSVs for root and chord_class

# dataset options: 'combined', 'root', 'chord_class'
#train_loader, test_loader, num_classes = data_processer.build_data_loaders(device=device, dataset='combined', nrows=None)
train_loader, test_loader, num_classes = data_processer.build_data_loaders(device=device, dataset='root', nrows=None) # set nrows to shrink dataset for testing
#train_loader, test_loader, num_classes = data_processer.build_data_loaders(device=device, dataset='chord_class', nrows=2000) # set nrows to shrink dataset for testing

#print(f"Number of root classes: {root_num_classes}")
print(f"Number of chord classes: {num_classes}")
# Out:
# INFO: Downloading ['metadata'] to c:\Users\User\Documents\OMSCS\CS7643\amadeus-ex-machina\data\raw
# INFO: [metadata] downloading billboard-2.0-index.csv
# INFO: c:\Users\User\Documents\OMSCS\CS7643\amadeus-ex-machina\data\raw\billboard-2.0-index.csv already exists and will not be downloaded. Rerun with force_overwrite=True to delete this file and force the download.
# Found 890 tracks in the dataset.
# Processing dataset as sequential data
# Processed track 3 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 4 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 6 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 10 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 12 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 15 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 16 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 18 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 19 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 21 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 22 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 23 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 25 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 26 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 27 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 29 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 30 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 33 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 34 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 35 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 37 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 39 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 40 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 41 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 43 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 44 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 46 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 49 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 50 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 51 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 53 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 54 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 55 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 56 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 59 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 61 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 62 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 64 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 66 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 67 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 68 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 70 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 71 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 72 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 73 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 74 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 75 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 77 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 78 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 79 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 81 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 83 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 85 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 86 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 88 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 89 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 91 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 92 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 94 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 95 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 97 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 99 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 100 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 101 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 102 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 104 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 105 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 106 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 107 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 109 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 111 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 112 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 114 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 115 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 116 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 119 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 120 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 122 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 123 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 124 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 126 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 127 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 128 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 130 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 131 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 133 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 134 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 139 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 140 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 141 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 145 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 147 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 148 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 149 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 150 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 153 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 154 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 155 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 157 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 158 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 159 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 160 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 162 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 167 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 168 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 169 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 170 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 172 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 176 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 177 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 179 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 180 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 181 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 182 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 183 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 184 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 185 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 187 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 188 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 190 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 191 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 192 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 193 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 194 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 195 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 196 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 198 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 199 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 202 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 203 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 204 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 205 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track
and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 748 and appended data to combined CSV.
# Processing dataset as sequential data
# ...
# Processing dataset as sequential data
# Processed track 1134 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1135 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1136 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1138 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1139 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1140 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1141 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1142 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1143 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1145 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1146 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1147 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1148 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1149 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1150 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1151 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1152 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1153 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1154 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1155 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1157 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1160 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1161 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1162 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1163 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1164 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1166 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1167 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1168 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1169 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1170 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1171 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1173 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1174 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1177 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1178 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1180 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1181 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1182 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1183 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1186 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1188 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1190 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1192 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1193 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1194 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1197 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1200 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1201 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1203 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1204 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1208 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1210 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1211 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1212 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1213 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1217 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1218 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1220 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1221 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1222 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1223 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1225 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1226 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1227 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1228 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1229 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1232 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1234 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1235 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1237 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1239 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1240 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1242 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1244 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1245 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1246 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1247 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1248 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1249 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1250 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1253 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1256 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1257 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1258 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1260 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1261 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1263 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1265 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1266 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1267 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1268 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1269 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1270 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1271 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1272 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1273 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1274 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1276 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1277 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1279 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1280 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1281 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1282 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1283 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1285 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1286 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1287 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1289 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1290 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1292 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1296 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1297 and appended data to combined CSV.
# Processing dataset as sequential data
# Processed track 1300 and appended data to combined CSV.
# All data processed and saved to data\combined_data.csv
# Preparing model data...
# Loading the root CSV file...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[24], line 18
#      13     data_processer.process_billboard_data(combined_notation=True, chord_vocab='majmin7inv', log_fail_only=False)
#      14     # combined notation is standard billboard notation (C:maj), setting False creates separate CSVs for root and chord_class
#      15
#      16 # dataset options: 'combined', 'root', 'chord_class'
#      17 #train_loader, test_loader, num_classes = data_processer.build_data_loaders(device=device, dataset='combined', nrows=None)
# ---> 18 train_loader, test_loader, num_classes = data_processer.build_data_loaders(device=device, dataset='root', nrows=None) # set nrows to shrink dataset for testing
#      19 #train_loader, test_loader, num_classes = data_processer.build_data_loaders(device=device, dataset='chord_class', nrows=2000) # set nrows to shrink dataset for testing
#      20
#      21 #print(f"Number of root classes: {root_num_classes}")
#      22 print(f"Number of chord classes: {num_classes}")
#
# File c:\Users\User\Documents\OMSCS\CS7643\amadeus-ex-machina\data\data_loader.py:339, in MirDataProcessor.build_data_loaders(self, dataset, nrows, device)
#     337 """Creates data loaders from the preprocessed model data."""
#     338 print("Preparing model data...")
# --> 339 X_train, X_test, y_train, y_test = self.prepare_model_data(dataset=dataset, nrows=nrows)
#     341 # Determine the number of classes
#     342 num_classes = len(self.label_encoder.classes_)
#
# File c:\Users\User\Documents\OMSCS\CS7643\amadeus-ex-machina\data\data_loader.py:213, in MirDataProcessor.prepare_model_data(self, dataset, nrows)
#     210     case 'chord_class':
#     211         csv_path = self.chord_class_csv_path
# --> 213 combined_df = pd.read_csv(csv_path, header=None, nrows=nrows)
#     214 data = combined_df.values
#     216 if self.process_sequential:
#
# File c:\Users\User\miniconda3\envs\amadeus-ex-machina\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\User\miniconda3\envs\amadeus-ex-machina\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\User\miniconda3\envs\amadeus-ex-machina\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\User\miniconda3\envs\amadeus-ex-machina\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\User\miniconda3\envs\amadeus-ex-machina\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data\\root_data.csv'

# %%
# NOTE: Do not assume these values are anything but trash, they're just here for testing

SOLVER_PARAMS = {
    Solver : {
        "device": device,
        "batch_size": 256,
        "epochs": 50,
        "early_stop_epochs": 5, # early stop after n epochs without improvement, 0 to disable
        "warmup_epochs": 0, # 0 to disable
        "dtype": "float16",
        "train_dataloader": train_loader, # must be DataLoader object
        "valid_dataloader": test_loader, # must be DataLoader object
    }
}

MODEL_PARAMS = {
    CRNNModel: {
        "input_features": 24,
        "num_classes": num_classes,
        "hidden_size": 512,
        "cnn_params": {
            "n_blocks": 1,
            "block_depth": 3,
            "pad": 1,
            "stride": 1,
            "k_conv": 3,
            "dropout": 0.2,
            "out_channels": 64
        }
    }
}

OPTIM_PARAMS = {
    torch.optim.Adam : {
        "lr": 0.002,
    }
}

SCHED_PARAMS = {
    torch.optim.lr_scheduler.ReduceLROnPlateau : {
        "patience": 3,
        "verbose": True,
    }
}

CRITERION_PARAMS = {
    torch.nn.CrossEntropyLoss : {}
}

PARAM_SET = {
    "solver": SOLVER_PARAMS,
    "model" : MODEL_PARAMS,
    "optim" : OPTIM_PARAMS,
    "sched" : SCHED_PARAMS,
    "criterion" : CRITERION_PARAMS,
}

# %%
model = list(MODEL_PARAMS.keys())[0](**MODEL_PARAMS[list(MODEL_PARAMS.keys())[0]])
optimizer = list(OPTIM_PARAMS.keys())[0](**(OPTIM_PARAMS[list(OPTIM_PARAMS.keys())[0]] | {'params': model.parameters()}))
scheduler = list(SCHED_PARAMS.keys())[0](**(SCHED_PARAMS[list(SCHED_PARAMS.keys())[0]] | {'optimizer': optimizer}))
criterion = list(CRITERION_PARAMS.keys())[0](**CRITERION_PARAMS[list(CRITERION_PARAMS.keys())[0]])
solver = Solver(**(SOLVER_PARAMS[Solver] | {'model': model, 'optimizer': optimizer, 'scheduler': scheduler, 'criterion': criterion}))

solver.train_and_evaluate(plot_results=True)

# %%
import pandas as pd
import pickle

def save_history(solver, filename='history.pkl'):
    # Create a DataFrame from the history lists
    history_df = pd.DataFrame({
        'Train Accuracy': solver.train_accuracy_history,
        'Validation Accuracy': solver.valid_accuracy_history,
        'Train Loss': solver.train_loss_history,
        'Validation Loss': solver.valid_loss_history
    })

    # Pickle the DataFrame to the specified file
    with open(filename, 'wb') as file:
        pickle.dump(history_df, file)

    print(f'History saved to {filename}')

def load_history(self, filename='history.pkl'):
    # Load the pickled DataFrame from the file
    with open(filename, 'rb') as file:
        history_df = pickle.load(file)

    # If the class attributes need to be repopulated from the DataFrame:
    self.train_accuracy_history = history_df['Train Accuracy'].tolist()
    self.valid_accuracy_history = history_df['Validation Accuracy'].tolist()
    self.train_loss_history = history_df['Train Loss'].tolist()
    self.valid_loss_history = history_df['Validation Loss'].tolist()

    print(f'History loaded from {filename}')

# %%
save_history(solver, 'CRNN_history_class.pkl')
# Out:
# History saved to CRNN_history.pkl

# %%
my_study = "crnn"

output_folder = Path("griddy")

hit_griddy(my_study, param_set=PARAM_SET, out_dir=output_folder, n_trials=2, n_jobs=2, prune=False, resume=False, trial_metric=TrialMetric.LOSS)
# NOTE: modest values of n_trials and n_jobs set here for testing, set your values accordingly
